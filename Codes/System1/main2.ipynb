# %% [markdown]
# # Simulation code of System\#1
#
# <img src="FigureFolder/System1.png" width="400">
#
# A structurally simple radial power network is considered, where $n$ generators jointly supply power to a single large load. Therefore, a failure on a transmission line may directly result in load loss, making it possible to highlight the effects of different approaches to handling probabilities.
#
# This notebook conducts simulations based on the physical mechanism of <font color='red'>damage caused by cumulative fatigue</font>.
#
# With Python and Jupyter Notebook properly configured, you can directly run this notebook from start to finish.

# %%
from Utils.Pyd.MonteCarlo_Utils import MonteCarlo_Naive_Sample, MonteCarlo_XULUO_Sample, \
    MonteCarlo_Past_Info_Sample, \
    MonteCarlo_Fatigue_Accumulation_Sample
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
from scipy.stats import norm
from scipy.interpolate import UnivariateSpline
import pickle

mpl.rcParams["mathtext.fontset"] = "stix"
mpl.rcParams["mathtext.default"] = "rm"

np.random.seed(613)
random.seed(613)

deltaT_name_list = {
    3 / 3600: r'$\Delta \it{t}=3\ \mathrm{s}$',
    1 / 120:  r'$\Delta \it{t}=30\ \mathrm{s}$',
    1 / 60: r'$\Delta \it{t}=1\ \mathrm{min}$',
    1 / 12: r'$\Delta \it{t}=5\ \mathrm{min}$',
    0.1: r'$\Delta \it{t}=0.1\ \mathrm{h}$',
    0.2: r'$\Delta \it{t}=0.2\ \mathrm{h}$',
    0.25: r'$\Delta \it{t}=15\ \mathrm{min}$',
    0.5: r'$\Delta \it{t}=0.5\ \mathrm{h}$',
    1: r'$\Delta \it{t}=1\ \mathrm{h}$',
    2: r'$\Delta \it{t}=2\ \mathrm{h}$',
    3: r'$\Delta \it{t}=3\ \mathrm{h}$'
}

# %%
# Parameter Setting
n = 10              # Number of generators/transmission lines
T = 48              # Total simulation time (in hours)
BASE_DELTAT = 3 / 3600 # 3 sec, Finest base time step (in hours)
deltaT_list = [BASE_DELTAT, 1 / 120 , 1 / 60, 1 / 12, 0.25, 1, 2, 3] # List of time steps to study
N_sim = 100         # Number of Monte Carlo simulations
P_gen = 10          # Maximum power of each generator (MW)

# %%
t = np.arange(0, T, BASE_DELTAT)

# %%
# Generate Load Demand Curve: Simulating Daily Load Variation with a Sine Function
L0 = 80
L1 = 5
L = L0 + L1 * np.sin(2 * np.pi * t / 24)

# %%
# Generate high-resolution gust wind speed series
def generate_gust_wind_series():
    N = round(T / BASE_DELTAT)
    t_sec = np.arange(N) * BASE_DELTAT * 3600
    dt_sec = BASE_DELTAT * 3600

    # Typhoon envelope (Gaussian shape)
    V_max = 45
    t_mid = t_sec.mean()
    sigma = T * 3600 / 4 * 1.6
    envelope = V_max * np.exp(-((t_sec - t_mid)**2) / (2 * sigma**2))

    # Generate AR(1) noise
    rho = 0.995 - 0.035
    noise = np.zeros(N)
    for i in range(1, N):
        noise[i] = rho * noise[i-1] + np.random.randn() * np.sqrt(1 - rho**2)

    amplitude_factor = 0.04
    w = envelope + envelope * amplitude_factor * noise
    w = np.clip(w, a_min=0, a_max=53 - 3)
    return w

w_example = generate_gust_wind_series()
w = np.zeros((N_sim, w_example.shape[0]))
for i in range(N_sim):
    w[i, :] = generate_gust_wind_series()

# %%
# Parameters of the Cumulative Fatigue Damage Theory
a = 1.9249e-7
b = 0.0055
v0_mu = 20
v0_sigma = 1.2 * 0
vmax_mu = 53
vmax_sigma = 5.0 * 0
Dres_mu = 0.2
Dres_sigma = 0.05 * 0
v0 = np.random.normal(v0_mu, v0_sigma, size=n)
vmax = np.random.normal(vmax_mu, vmax_sigma, size=n)
Dres = np.random.normal(Dres_mu, Dres_sigma, size=n)

# (Attempt to fit these parameters using historical data)
# See Utils/experiment_fitting2.ipynb
para_id_result = {
    'Dres': 0.20033761790684773,
    'a': 1.917974392013611e-07,
    'b': 0.005502413917601797,
    'v0': 19.465035610201653,
    'vmax': 53.14449273773345}

# %%
# Fragility curve, described by a log-normal distribution
# See Utils/experiment_fitting2.ipynb
mu = 3.97110346
sigma = 0.09959508

# %%
# Convert high-resolution data to low-resolution data
def downsample(data, deltaT, method):
    if deltaT <= BASE_DELTAT:
        return data
    """
    Convert high-resolution data to low-resolution data  
    :param data: High-resolution data  
    :param deltaT: Low-resolution time step (hours)  
    :return: Low-resolution data
    """
    n_samples = int(len(data) * BASE_DELTAT / deltaT)
    downsampled_data = np.zeros(n_samples)
    for i in range(n_samples):
        if method == "mean":
            downsampled_data[i] = np.mean(data[int(i * deltaT / BASE_DELTAT):int((i + 1) * deltaT / BASE_DELTAT)])
        else:
            raise ValueError("Invalid method")
    return downsampled_data

# %% [markdown]
# ## (a)
#
# Independent sampling directly based on the vulnerability curve

# %%
monte_carlo_naive_sample = []
for deltaT in deltaT_list:
    print(f">>>deltaT = {deltaT}")
    L_downsampled = downsample(L, deltaT, 'mean')
    w_downsampled = np.zeros((N_sim, round(len(w_example) * (BASE_DELTAT / deltaT))))
    for i in range(N_sim):
        w_downsampled[i, :] = downsample(w[i, :], deltaT, 'mean')
    monte_carlo_naive_sample.append(MonteCarlo_Naive_Sample(n, T, deltaT, N_sim, P_gen,
                                                            L_downsampled, w_downsampled, 
                                                            fragility_params={'mu': mu, 'sigma': sigma}))
# Out:
# >>>deltaT = 0.0008333333333333334
# Simulation 1/100 (deltaT=0.0008333333333333334)
# Simulation 2/100 (deltaT=0.0008333333333333334)
# Simulation 3/100 (deltaT=0.0008333333333333334)
# Simulation 4/100 (deltaT=0.0008333333333333334)
# Simulation 5/100 (deltaT=0.0008333333333333334)
# Simulation 6/100 (deltaT=0.0008333333333333334)
# Simulation 7/100 (deltaT=0.0008333333333333334)
# Simulation 8/100 (deltaT=0.0008333333333333334)
# Simulation 9/100 (deltaT=0.0008333333333333334)
# Simulation 10/100 (deltaT=0.0008333333333333334)
# Simulation 11/100 (deltaT=0.0008333333333333334)
# Simulation 12/100 (deltaT=0.0008333333333333334)
# Simulation 13/100 (deltaT=0.0008333333333333334)
# Simulation 14/100 (deltaT=0.0008333333333333334)
# Simulation 15/100 (deltaT=0.0008333333333333334)
# Simulation 16/100 (deltaT=0.0008333333333333334)
# Simulation 17/100 (deltaT=0.0008333333333333334)
# Simulation 18/100 (deltaT=0.0008333333333333334)
# Simulation 19/100 (deltaT=0.0008333333333333334)
# Simulation 72/100 (deltaT=0.08333333333333333)
# Simulation 73/100 (deltaT=0.08333333333333333)
# Simulation 74/100 (deltaT=0.08333333333333333)
# Simulation 75/100 (deltaT=0.08333333333333333)
# Simulation 76/100 (deltaT=0.08333333333333333)
# Simulation 77/100 (deltaT=0.08333333333333333)
# Simulation 78/100 (deltaT=0.08333333333333333)
# Simulation 79/100 (deltaT=0.08333333333333333)
# Simulation 80/100 (deltaT=0.08333333333333333)
# Simulation 81/100 (deltaT=0.08333333333333333)
# Simulation 82/100 (deltaT=0.08333333333333333)
# Simulation 83/100 (deltaT=0.08333333333333333)
# Simulation 84/100 (deltaT=0.08333333333333333)
# Simulation 85/100 (deltaT=0.08333333333333333)
# Simulation 86/100 (deltaT=0.08333333333333333)
# Simulation 87/100 (deltaT=0.08333333333333333)
# Simulation 88/100 (deltaT=0.08333333333333333)
# Simulation 89/100 (deltaT=0.08333333333333333)
# Simulation 90/100 (deltaT=0.08333333333333333)
# Simulation 91/100 (deltaT=0.08333333333333333)
# Simulation 92/100 (deltaT=0.08333333333333333)
# Simulation 93/100 (deltaT=0.08333333333333333)
# Simulation 94/100 (deltaT=0.08333333333333333)
# Simulation 95/100 (deltaT=0.08333333333333333)
# Simulation 96/100 (deltaT=0.08333333333333333)
# Simulation 97/100 (deltaT=0.08333333333333333)
# Simulation 98/100 (deltaT=0.08333333333333333)
# Simulation 99/100 (deltaT=0.08333333333333333)
# Simulation 100/100 (deltaT=0.08333333333333333)
# >>>deltaT = 0.25
# Simulation 1/100 (deltaT=0.25)
# Simulation 2/100 (deltaT=0.25)
# Simulation 3/100 (deltaT=0.25)
# Simulation 4/100 (deltaT=0.25)
# Simulation 5/100 (deltaT=0.25)
# Simulation 6/100 (deltaT=0.25)
# Simulation 7/100 (deltaT=0.25)
# Simulation 8/100 (deltaT=0.25)
# Simulation 9/100 (deltaT=0.25)
# Simulation 10/100 (deltaT=0.25)
# Simulation 11/100 (deltaT=0.25)
# Simulation 12/100 (deltaT=0.25)
# Simulation 13/100 (deltaT=0.25)
# Simulation 14/100 (deltaT=0.25)
# Simulation 15/100 (deltaT=0.25)
# Simulation 16/100 (deltaT=0.25)
# Simulation 17/100 (deltaT=0.25)
# Simulation 18/100 (deltaT=0.25)
# Simulation 19/100 (deltaT=0.25)
# Simulation 20/100 (deltaT=0.25)
# Simulation 21/100 (deltaT=0.25)
# Simulation 22/100 (deltaT=0.25)
# Simulation 23/100 (deltaT=0.25)
# Simulation 24/100 (deltaT=0.25)
# Simulation 25/100 (deltaT=0.25)
# Simulation 26/100 (deltaT=0.25)
# Simulation 27/100 (deltaT=0.25)
# Simulation 28/100 (deltaT=0.25)
# Simulation 29/100 (deltaT=0.25)
# Simulation 30/100 (deltaT=0.25)
# Simulation 31/100 (deltaT=0.25)
# Simulation 32/100 (deltaT=0.25)
# Simulation 33/100 (deltaT=0.25)
# Simulation 34/100 (deltaT=0.25)
# Simulation 35/100 (deltaT=0.25)
# Simulation 36/100 (deltaT=0.25)
# Simulation 37/100 (deltaT=0.25)
# Simulation 38/100 (deltaT=0.25)
# Simulation 39/100 (deltaT=0.25)
# Simulation 40/100 (deltaT=0.25)
# Simulation 41/100 (deltaT=0.25)
# Simulation 42/100 (deltaT=0.25)
# Simulation 43/100 (deltaT=0.25)
# Simulation 44/100 (deltaT=0.25)
# Simulation 45/100 (deltaT=0.25)
# Simulation 46/100 (deltaT=0.25)
# Simulation 47/100 (deltaT=0.25)
# Simulation 48/100 (deltaT=0.25)
# Simulation 49/100 (deltaT=0.25)
# Simulation 50/100 (deltaT=0.25)
# Simulation 51/100 (deltaT=0.25)
# Simulation 52/100 (deltaT=0.25)
# Simulation 53/100 (deltaT=0.25)
# Simulation 54/100 (deltaT=0.25)
# Simulation 55/100 (deltaT=0.25)
# Simulation 56/100 (deltaT=0.25)
# Simulation 57/100 (deltaT=0.25)
# Simulation 58/100 (deltaT=0.25)
# Simulation 59/100 (deltaT=0.25)
# Simulation 60/100 (deltaT=0.25)
# Simulation 61/100 (deltaT=0.25)
# Simulation 62/100 (deltaT=0.25)
# Simulation 63/100 (deltaT=0.25)
# Simulation 64/100 (deltaT=0.25)
# Simulation 65/100 (deltaT=0.25)
# Simulation 66/100 (deltaT=0.25)
# Simulation 67/100 (deltaT=0.25)
# Simulation 68/100 (deltaT=0.25)
# Simulation 69/100 (deltaT=0.25)
# Simulation 70/100 (deltaT=0.25)
# Simulation 71/100 (deltaT=0.25)
# Simulation 72/100 (deltaT=0.25)
# Simulation 73/100 (deltaT=0.25)
# Simulation 74/100 (deltaT=0.25)
# Simulation 75/100 (deltaT=0.25)
# Simulation 76/100 (deltaT=0.25)
# Simulation 77/100 (deltaT=0.25)
# Simulation 78/100 (deltaT=0.25)
# Simulation 79/100 (deltaT=0.25)
# Simulation 80/100 (deltaT=0.25)
# Simulation 81/100 (deltaT=0.25)
# Simulation 82/100 (deltaT=0.25)
# Simulation 83/100 (deltaT=0.25)
# Simulation 84/100 (deltaT=0.25)
# Simulation 85/100 (deltaT=0.25)
# Simulation 86/100 (deltaT=0.25)
# Simulation 87/100 (deltaT=0.25)
# Simulation 88/100 (deltaT=0.25)
# Simulation 89/100 (deltaT=0.25)
# Simulation 90/100 (deltaT=0.25)
# Simulation 91/100 (deltaT=0.25)
# Simulation 92/100 (deltaT=0.25)
# Simulation 93/100 (deltaT=0.25)
# Simulation 94/100 (deltaT=0.25)
# Simulation 95/100 (deltaT=0.25)
# Simulation 96/100 (deltaT=0.25)
# Simulation 97/100 (deltaT=0.25)
# Simulation 98/100 (deltaT=0.25)
# Simulation 99/100 (deltaT=0.25)
# Simulation 100/100 (deltaT=0.25)
# >>>deltaT = 1
# Simulation 1/100 (deltaT=1)
# Simulation 2/100 (deltaT=1)
# Simulation 3/100 (deltaT=1)
# Simulation 4/100 (deltaT=1)
# Simulation 5/100 (deltaT=1)
# Simulation 6/100 (deltaT=1)
# Simulation 7/100 (deltaT=1)
# Simulation 8/100 (deltaT=1)
# Simulation 9/100 (deltaT=1)
# Simulation 10/100 (deltaT=1)
# Simulation 11/100 (deltaT=1)
# Simulation 12/100 (deltaT=1)
# Simulation 95/100 (deltaT=1)
# Simulation 96/100 (deltaT=1)
# Simulation 97/100 (deltaT=1)
# Simulation 98/100 (deltaT=1)
# Simulation 99/100 (deltaT=1)
# Simulation 100/100 (deltaT=1)
# >>>deltaT = 2
# Simulation 1/100 (deltaT=2)
# Simulation 2/100 (deltaT=2)
# Simulation 3/100 (deltaT=2)
# Simulation 4/100 (deltaT=2)
# Simulation 5/100 (deltaT=2)
# Simulation 6/100 (deltaT=2)
# Simulation 7/100 (deltaT=2)
# Simulation 8/100 (deltaT=2)
# Simulation 9/100 (deltaT=2)
# Simulation 10/100 (deltaT=2)
# Simulation 11/100 (deltaT=2)
# Simulation 12/100 (deltaT=2)
# Simulation 13/100 (deltaT=2)
# Simulation 14/100 (deltaT=2)
# Simulation 15/100 (deltaT=2)
# Simulation 16/100 (deltaT=2)
# Simulation 17/100 (deltaT=2)
# Simulation 18/100 (deltaT=2)
# Simulation 19/100 (deltaT=2)
# Simulation 20/100 (deltaT=2)
# Simulation 21/100 (deltaT=2)
# Simulation 22/100 (deltaT=2)
# Simulation 23/100 (deltaT=2)
# Simulation 24/100 (deltaT=2)
# Simulation 25/100 (deltaT=2)
# Simulation 26/100 (deltaT=2)
# Simulation 27/100 (deltaT=2)
# Simulation 28/100 (deltaT=2)
# Simulation 29/100 (deltaT=2)
# Simulation 30/100 (deltaT=2)
# Simulation 31/100 (deltaT=2)
# Simulation 32/100 (deltaT=2)
# Simulation 33/100 (deltaT=2)
# Simulation 34/100 (deltaT=2)
# Simulation 35/100 (deltaT=2)
# Simulation 36/100 (deltaT=2)
# Simulation 37/100 (deltaT=2)
# Simulation 38/100 (deltaT=2)
# Simulation 39/100 (deltaT=2)
# Simulation 40/100 (deltaT=2)
# Simulation 41/100 (deltaT=2)
# Simulation 42/100 (deltaT=2)
# Simulation 43/100 (deltaT=2)
# Simulation 44/100 (deltaT=2)
# Simulation 45/100 (deltaT=2)
# Simulation 46/100 (deltaT=2)
# Simulation 47/100 (deltaT=2)
# Simulation 48/100 (deltaT=2)
# Simulation 49/100 (deltaT=2)
# Simulation 50/100 (deltaT=2)
# Simulation 51/100 (deltaT=2)
# Simulation 52/100 (deltaT=2)
# Simulation 53/100 (deltaT=2)
# Simulation 54/100 (deltaT=2)
# Simulation 55/100 (deltaT=2)
# Simulation 56/100 (deltaT=2)
# Simulation 57/100 (deltaT=2)
# Simulation 58/100 (deltaT=2)
# Simulation 59/100 (deltaT=2)
# Simulation 60/100 (deltaT=2)
# Simulation 61/100 (deltaT=2)
# Simulation 62/100 (deltaT=2)
# Simulation 63/100 (deltaT=2)
# Simulation 64/100 (deltaT=2)
# Simulation 65/100 (deltaT=2)
# Simulation 66/100 (deltaT=2)
# Simulation 67/100 (deltaT=2)
# Simulation 68/100 (deltaT=2)
# Simulation 69/100 (deltaT=2)
# Simulation 70/100 (deltaT=2)
# Simulation 71/100 (deltaT=2)
# Simulation 72/100 (deltaT=2)
# Simulation 73/100 (deltaT=2)
# Simulation 74/100 (deltaT=2)
# Simulation 75/100 (deltaT=2)
# Simulation 76/100 (deltaT=2)
# Simulation 77/100 (deltaT=2)
# Simulation 78/100 (deltaT=2)
# Simulation 79/100 (deltaT=2)
# Simulation 80/100 (deltaT=2)
# Simulation 81/100 (deltaT=2)
# Simulation 82/100 (deltaT=2)
# Simulation 83/100 (deltaT=2)
# Simulation 84/100 (deltaT=2)
# Simulation 85/100 (deltaT=2)
# Simulation 86/100 (deltaT=2)
# Simulation 87/100 (deltaT=2)
# Simulation 88/100 (deltaT=2)
# Simulation 89/100 (deltaT=2)
# Simulation 90/100 (deltaT=2)
# Simulation 91/100 (deltaT=2)
# Simulation 92/100 (deltaT=2)
# Simulation 93/100 (deltaT=2)
# Simulation 94/100 (deltaT=2)
# Simulation 95/100 (deltaT=2)
# Simulation 96/100 (deltaT=2)
# Simulation 97/100 (deltaT=2)
# Simulation 98/100 (deltaT=2)
# Simulation 99/100 (deltaT=2)
# Simulation 100/100 (deltaT=2)
# >>>deltaT = 3
# Simulation 1/100 (deltaT=3)
# Simulation 2/100 (deltaT=3)
# Simulation 3/100 (deltaT=3)
# Simulation 4/100 (deltaT=3)
# Simulation 5/100 (deltaT=3)
# Simulation 6/100 (deltaT=3)
# Simulation 7/100 (deltaT=3)
# Simulation 8/100 (deltaT=3)
# Simulation 9/100 (deltaT=3)
# Simulation 10/100 (deltaT=3)
# Simulation 11/100 (deltaT=3)
# Simulation 12/100 (deltaT=3)
# Simulation 13/100 (deltaT=3)
# Simulation 14/100 (deltaT=3)
# Simulation 15/100 (deltaT=3)
# Simulation 16/100 (deltaT=3)
# Simulation 17/100 (deltaT=3)
# Simulation 18/100 (deltaT=3)
# Simulation 19/100 (deltaT=3)
# Simulation 20/100 (deltaT=3)
# Simulation 21/100 (deltaT=3)
# Simulation 22/100 (deltaT=3)
# Simulation 23/100 (deltaT=3)
# Simulation 24/100 (deltaT=3)
# Simulation 25/100 (deltaT=3)
# Simulation 26/100 (deltaT=3)
# Simulation 27/100 (deltaT=3)
# Simulation 28/100 (deltaT=3)
# Simulation 29/100 (deltaT=3)
# Simulation 30/100 (deltaT=3)
# Simulation 31/100 (deltaT=3)
# Simulation 32/100 (deltaT=3)
# Simulation 33/100 (deltaT=3)
# Simulation 34/100 (deltaT=3)
# Simulation 35/100 (deltaT=3)
# Simulation 36/100 (deltaT=3)
# Simulation 37/100 (deltaT=3)
# Simulation 38/100 (deltaT=3)
# Simulation 39/100 (deltaT=3)
# Simulation 40/100 (deltaT=3)
# Simulation 41/100 (deltaT=3)
# Simulation 42/100 (deltaT=3)
# Simulation 43/100 (deltaT=3)
# Simulation 44/100 (deltaT=3)
# Simulation 45/100 (deltaT=3)
# Simulation 46/100 (deltaT=3)
# Simulation 47/100 (deltaT=3)
# Simulation 48/100 (deltaT=3)
# Simulation 49/100 (deltaT=3)
# Simulation 50/100 (deltaT=3)
# Simulation 51/100 (deltaT=3)
# Simulation 52/100 (deltaT=3)
# Simulation 53/100 (deltaT=3)
# Simulation 54/100 (deltaT=3)
# Simulation 55/100 (deltaT=3)
# Simulation 56/100 (deltaT=3)
# Simulation 57/100 (deltaT=3)
# Simulation 58/100 (deltaT=3)
# Simulation 59/100 (deltaT=3)
# Simulation 60/100 (deltaT=3)
# Simulation 61/100 (deltaT=3)
# Simulation 62/100 (deltaT=3)
# Simulation 63/100 (deltaT=3)
# Simulation 64/100 (deltaT=3)
# Simulation 65/100 (deltaT=3)
# Simulation 66/100 (deltaT=3)
# Simulation 67/100 (deltaT=3)
# Simulation 68/100 (deltaT=3)
# Simulation 69/100 (deltaT=3)
# Simulation 70/100 (deltaT=3)
# Simulation 71/100 (deltaT=3)
# Simulation 72/100 (deltaT=3)
# Simulation 73/100 (deltaT=3)
# Simulation 74/100 (deltaT=3)
# Simulation 75/100 (deltaT=3)
# Simulation 76/100 (deltaT=3)
# Simulation 77/100 (deltaT=3)
# Simulation 78/100 (deltaT=3)
# Simulation 79/100 (deltaT=3)
# Simulation 80/100 (deltaT=3)
# Simulation 81/100 (deltaT=3)
# Simulation 82/100 (deltaT=3)
# Simulation 83/100 (deltaT=3)
# Simulation 84/100 (deltaT=3)
# Simulation 85/100 (deltaT=3)
# Simulation 86/100 (deltaT=3)
# Simulation 87/100 (deltaT=3)
# Simulation 88/100 (deltaT=3)
# Simulation 89/100 (deltaT=3)
# Simulation 90/100 (deltaT=3)
# Simulation 91/100 (deltaT=3)
# Simulation 92/100 (deltaT=3)
# Simulation 93/100 (deltaT=3)
# Simulation 94/100 (deltaT=3)
# Simulation 95/100 (deltaT=3)
# Simulation 96/100 (deltaT=3)
# Simulation 97/100 (deltaT=3)
# Simulation 98/100 (deltaT=3)
# Simulation 99/100 (deltaT=3)
# Simulation 100/100 (deltaT=3)

# %%
f_save = open("./SolutionFolder/MonteCarlo_Naive_Sample_Fatigue.pkl", 'wb')
pickle.dump(monte_carlo_naive_sample, f_save)
f_save.close()

# %%
with open("./SolutionFolder/MonteCarlo_Naive_Sample_Fatigue.pkl", 'rb') as file:
    monte_carlo_naive_sample = pickle.loads(file.read())
    monte_carlo_naive_sample = [monte_carlo_naive_sample[m]["all_load_served"] 
                                for m in range(len(monte_carlo_naive_sample))]
M = len(deltaT_list)
fig = plt.figure(figsize=(6.5, 4))
ax = fig.add_subplot(111)
plt.rc('font', family='Times New Roman', size=15)

colors = sns.color_palette("deep", n_colors=M)
for m in range(0, M-1):
    t = np.arange(0, T, deltaT_list[m]) + deltaT_list[m] / 2
    L_downsampled = downsample(L, deltaT_list[m], 'mean')
    color = colors[m]
    load_served_ratio = monte_carlo_naive_sample[m] / L_downsampled
    df = {'Load Served Ratio': [], 'Time (hours)': []}
    for i in range(N_sim):
        df['Load Served Ratio'].extend(load_served_ratio[i])
        df['Time (hours)'].extend(t)
    sns.lineplot(
        data=df,
        x='Time (hours)',
        y='Load Served Ratio',
        errorbar=('sd', 0.5),
        label=deltaT_name_list[deltaT_list[m]],
        color=colors[m],
        linewidth=2.5
    )
plt.ylim(0 - 0.05, 1.05)
plt.xlabel('Time', fontdict={'family': 'times new roman', 'size': 17, 'style': 'normal'})
plt.ylabel('Load Served Ratio', fontdict={'family': 'times new roman', 'size': 17, 'style': 'normal'})
ax.set_xticks(range(0, T+1, 6))
xticklabels = []
for i in range(0, T+1, 6):
    if i <= 24:
        xticklabels.append(f'{i:02d}:00')
    else:
        xticklabels.append(f'{i-24:02d}:00')
ax.set_xticklabels(xticklabels,font={'family': 'times new roman', 'size': 14, 'style': 'normal'},
                   rotation=0)
ax.set_yticks(np.arange(0, 1.01, 0.2))
yticklabels = [f'{i:d}%' for i in np.arange(0, 101, 20)]
ax.set_yticklabels(yticklabels,font={'family': 'times new roman', 'size': 14, 'style': 'normal'},
                   rotation=0)

plt.legend(loc='best',
           prop={'family': 'times new roman', 'size': 14},
           edgecolor='1.0',
           framealpha=0.8
)

ax.grid(axis='both', color='grey', alpha=0.3, linestyle='--', linewidth=1.2)
ax.spines['bottom'].set_linewidth(1.8)
ax.spines['top'].set_linewidth(1.8)
ax.spines['left'].set_linewidth(1.8)
ax.spines['right'].set_linewidth(1.8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## (b)
#
# Method based on fixed component resilience attributes (in [8])

# %%
monte_carlo_XULUO_sample = []
for deltaT in deltaT_list:
    print(f">>>deltaT = {deltaT}")
    L_downsampled = downsample(L, deltaT, 'mean')
    w_downsampled = np.zeros((N_sim, round(len(w_example) * BASE_DELTAT / deltaT)))
    for i in range(N_sim):
        w_downsampled[i, :] = downsample(w[i, :], deltaT, 'mean')
    monte_carlo_XULUO_sample.append(MonteCarlo_XULUO_Sample(n, T, deltaT, N_sim, P_gen,
                                                            L_downsampled, w_downsampled, 
                                                            fragility_params={'mu': mu, 'sigma': sigma}))
# Out:
# >>>deltaT = 0.0008333333333333334
# Simulation 1/100 (deltaT=0.0008333333333333334)
# Simulation 2/100 (deltaT=0.0008333333333333334)
# Simulation 3/100 (deltaT=0.0008333333333333334)
# Simulation 4/100 (deltaT=0.0008333333333333334)
# Simulation 5/100 (deltaT=0.0008333333333333334)
# Simulation 6/100 (deltaT=0.0008333333333333334)
# Simulation 7/100 (deltaT=0.0008333333333333334)
# Simulation 8/100 (deltaT=0.0008333333333333334)
# Simulation 9/100 (deltaT=0.0008333333333333334)
# Simulation 10/100 (deltaT=0.0008333333333333334)
# Simulation 11/100 (deltaT=0.0008333333333333334)
# Simulation 12/100 (deltaT=0.0008333333333333334)
# Simulation 13/100 (deltaT=0.0008333333333333334)
# Simulation 14/100 (deltaT=0.0008333333333333334)
# Simulation 15/100 (deltaT=0.0008333333333333334)
# Simulation 16/100 (deltaT=0.0008333333333333334)
# Simulation 17/100 (deltaT=0.0008333333333333334)
# Simulation 18/100 (deltaT=0.0008333333333333334)
# Simulation 19/100 (deltaT=0.0008333333333333334)
# Simulation 20/100 (deltaT=0.0008333333333333334)
# Simulation 21/100 (deltaT=0.0008333333333333334)
# Simulation 22/100 (deltaT=0.0008333333333333334)
# Simulation 23/100 (deltaT=0.0008333333333333334)
# Simulation 24/100 (deltaT=0.0008333333333333334)
# Simulation 25/100 (deltaT=0.0008333333333333334)
# Simulation 26/100 (deltaT=0.0008333333333333334)
# Simulation 27/100 (deltaT=0.0008333333333333334)
# Simulation 80/100 (deltaT=0.08333333333333333)
# Simulation 81/100 (deltaT=0.08333333333333333)
# Simulation 82/100 (deltaT=0.08333333333333333)
# Simulation 83/100 (deltaT=0.08333333333333333)
# Simulation 84/100 (deltaT=0.08333333333333333)
# Simulation 85/100 (deltaT=0.08333333333333333)
# Simulation 86/100 (deltaT=0.08333333333333333)
# Simulation 87/100 (deltaT=0.08333333333333333)
# Simulation 88/100 (deltaT=0.08333333333333333)
# Simulation 89/100 (deltaT=0.08333333333333333)
# Simulation 90/100 (deltaT=0.08333333333333333)
# Simulation 91/100 (deltaT=0.08333333333333333)
# Simulation 92/100 (deltaT=0.08333333333333333)
# Simulation 93/100 (deltaT=0.08333333333333333)
# Simulation 94/100 (deltaT=0.08333333333333333)
# Simulation 95/100 (deltaT=0.08333333333333333)
# Simulation 96/100 (deltaT=0.08333333333333333)
# Simulation 97/100 (deltaT=0.08333333333333333)
# Simulation 98/100 (deltaT=0.08333333333333333)
# Simulation 99/100 (deltaT=0.08333333333333333)
# Simulation 100/100 (deltaT=0.08333333333333333)
# >>>deltaT = 0.25
# Simulation 1/100 (deltaT=0.25)
# Simulation 2/100 (deltaT=0.25)
# Simulation 3/100 (deltaT=0.25)
# Simulation 4/100 (deltaT=0.25)
# Simulation 5/100 (deltaT=0.25)
# Simulation 6/100 (deltaT=0.25)
# Simulation 7/100 (deltaT=0.25)
# Simulation 8/100 (deltaT=0.25)
# Simulation 9/100 (deltaT=0.25)
# Simulation 10/100 (deltaT=0.25)
# Simulation 11/100 (deltaT=0.25)
# Simulation 12/100 (deltaT=0.25)
# Simulation 13/100 (deltaT=0.25)
# Simulation 14/100 (deltaT=0.25)
# Simulation 15/100 (deltaT=0.25)
# Simulation 16/100 (deltaT=0.25)
# Simulation 17/100 (deltaT=0.25)
# Simulation 18/100 (deltaT=0.25)
# Simulation 19/100 (deltaT=0.25)
# Simulation 20/100 (deltaT=0.25)
# Simulation 21/100 (deltaT=0.25)
# Simulation 22/100 (deltaT=0.25)
# Simulation 23/100 (deltaT=0.25)
# Simulation 24/100 (deltaT=0.25)
# Simulation 25/100 (deltaT=0.25)
# Simulation 26/100 (deltaT=0.25)
# Simulation 27/100 (deltaT=0.25)
# Simulation 28/100 (deltaT=0.25)
# Simulation 29/100 (deltaT=0.25)
# Simulation 30/100 (deltaT=0.25)
# Simulation 31/100 (deltaT=0.25)
# Simulation 32/100 (deltaT=0.25)
# Simulation 33/100 (deltaT=0.25)
# Simulation 34/100 (deltaT=0.25)
# Simulation 35/100 (deltaT=0.25)
# Simulation 36/100 (deltaT=0.25)
# Simulation 37/100 (deltaT=0.25)
# Simulation 38/100 (deltaT=0.25)
# Simulation 39/100 (deltaT=0.25)
# Simulation 40/100 (deltaT=0.25)
# Simulation 41/100 (deltaT=0.25)
# Simulation 42/100 (deltaT=0.25)
# Simulation 43/100 (deltaT=0.25)
# Simulation 44/100 (deltaT=0.25)
# Simulation 45/100 (deltaT=0.25)
# Simulation 46/100 (deltaT=0.25)
# Simulation 47/100 (deltaT=0.25)
# Simulation 48/100 (deltaT=0.25)
# Simulation 49/100 (deltaT=0.25)
# Simulation 50/100 (deltaT=0.25)
# Simulation 51/100 (deltaT=0.25)
# Simulation 52/100 (deltaT=0.25)
# Simulation 53/100 (deltaT=0.25)
# Simulation 54/100 (deltaT=0.25)
# Simulation 55/100 (deltaT=0.25)
# Simulation 56/100 (deltaT=0.25)
# Simulation 57/100 (deltaT=0.25)
# Simulation 58/100 (deltaT=0.25)
# Simulation 59/100 (deltaT=0.25)
# Simulation 60/100 (deltaT=0.25)
# Simulation 61/100 (deltaT=0.25)
# Simulation 62/100 (deltaT=0.25)
# Simulation 63/100 (deltaT=0.25)
# Simulation 64/100 (deltaT=0.25)
# Simulation 65/100 (deltaT=0.25)
# Simulation 66/100 (deltaT=0.25)
# Simulation 67/100 (deltaT=0.25)
# Simulation 68/100 (deltaT=0.25)
# Simulation 69/100 (deltaT=0.25)
# Simulation 70/100 (deltaT=0.25)
# Simulation 71/100 (deltaT=0.25)
# Simulation 72/100 (deltaT=0.25)
# Simulation 73/100 (deltaT=0.25)
# Simulation 74/100 (deltaT=0.25)
# Simulation 75/100 (deltaT=0.25)
# Simulation 76/100 (deltaT=0.25)
# Simulation 77/100 (deltaT=0.25)
# Simulation 78/100 (deltaT=0.25)
# Simulation 79/100 (deltaT=0.25)
# Simulation 80/100 (deltaT=0.25)
# Simulation 81/100 (deltaT=0.25)
# Simulation 82/100 (deltaT=0.25)
# Simulation 83/100 (deltaT=0.25)
# Simulation 84/100 (deltaT=0.25)
# Simulation 85/100 (deltaT=0.25)
# Simulation 86/100 (deltaT=0.25)
# Simulation 87/100 (deltaT=0.25)
# Simulation 88/100 (deltaT=0.25)
# Simulation 89/100 (deltaT=0.25)
# Simulation 90/100 (deltaT=0.25)
# Simulation 91/100 (deltaT=0.25)
# Simulation 92/100 (deltaT=0.25)
# Simulation 93/100 (deltaT=0.25)
# Simulation 94/100 (deltaT=0.25)
# Simulation 95/100 (deltaT=0.25)
# Simulation 96/100 (deltaT=0.25)
# Simulation 97/100 (deltaT=0.25)
# Simulation 98/100 (deltaT=0.25)
# Simulation 99/100 (deltaT=0.25)
# Simulation 100/100 (deltaT=0.25)
# >>>deltaT = 1
# Simulation 1/100 (deltaT=1)
# Simulation 2/100 (deltaT=1)
# Simulation 3/100 (deltaT=1)
# Simulation 4/100 (deltaT=1)
# Simulation 5/100 (deltaT=1)
# Simulation 6/100 (deltaT=1)
# Simulation 7/100 (deltaT=1)
# Simulation 8/100 (deltaT=1)
# Simulation 9/100 (deltaT=1)
# Simulation 10/100 (deltaT=1)
# Simulation 11/100 (deltaT=1)
# Simulation 12/100 (deltaT=1)
# Simulation 13/100 (deltaT=1)
# Simulation 14/100 (deltaT=1)
# Simulation 15/100 (deltaT=1)
# Simulation 16/100 (deltaT=1)
# Simulation 17/100 (deltaT=1)
# Simulation 18/100 (deltaT=1)
# Simulation 19/100 (deltaT=1)
# Simulation 20/100 (deltaT=1)
# Simulation 21/100 (deltaT=1)
# Simulation 22/100 (deltaT=1)
# Simulation 23/100 (deltaT=1)
# Simulation 5/100 (deltaT=2)
# Simulation 6/100 (deltaT=2)
# Simulation 7/100 (deltaT=2)
# Simulation 8/100 (deltaT=2)
# Simulation 9/100 (deltaT=2)
# Simulation 10/100 (deltaT=2)
# Simulation 11/100 (deltaT=2)
# Simulation 12/100 (deltaT=2)
# Simulation 13/100 (deltaT=2)
# Simulation 14/100 (deltaT=2)
# Simulation 15/100 (deltaT=2)
# Simulation 16/100 (deltaT=2)
# Simulation 17/100 (deltaT=2)
# Simulation 18/100 (deltaT=2)
# Simulation 19/100 (deltaT=2)
# Simulation 20/100 (deltaT=2)
# Simulation 21/100 (deltaT=2)
# Simulation 22/100 (deltaT=2)
# Simulation 23/100 (deltaT=2)
# Simulation 24/100 (deltaT=2)
# Simulation 25/100 (deltaT=2)
# Simulation 26/100 (deltaT=2)
# Simulation 27/100 (deltaT=2)
# Simulation 28/100 (deltaT=2)
# Simulation 29/100 (deltaT=2)
# Simulation 30/100 (deltaT=2)
# Simulation 31/100 (deltaT=2)
# Simulation 32/100 (deltaT=2)
# Simulation 33/100 (deltaT=2)
# Simulation 34/100 (deltaT=2)
# Simulation 35/100 (deltaT=2)
# Simulation 36/100 (deltaT=2)
# Simulation 37/100 (deltaT=2)
# Simulation 38/100 (deltaT=2)
# Simulation 39/100 (deltaT=2)
# Simulation 40/100 (deltaT=2)
# Simulation 41/100 (deltaT=2)
# Simulation 42/100 (deltaT=2)
# Simulation 43/100 (deltaT=2)
# Simulation 44/100 (deltaT=2)
# Simulation 45/100 (deltaT=2)
# Simulation 46/100 (deltaT=2)
# Simulation 47/100 (deltaT=2)
# Simulation 48/100 (deltaT=2)
# Simulation 49/100 (deltaT=2)
# Simulation 50/100 (deltaT=2)
# Simulation 51/100 (deltaT=2)
# Simulation 52/100 (deltaT=2)
# Simulation 53/100 (deltaT=2)
# Simulation 54/100 (deltaT=2)
# Simulation 55/100 (deltaT=2)
# Simulation 56/100 (deltaT=2)
# Simulation 57/100 (deltaT=2)
# Simulation 58/100 (deltaT=2)
# Simulation 59/100 (deltaT=2)
# Simulation 60/100 (deltaT=2)
# Simulation 61/100 (deltaT=2)
# Simulation 62/100 (deltaT=2)
# Simulation 63/100 (deltaT=2)
# Simulation 64/100 (deltaT=2)
# Simulation 65/100 (deltaT=2)
# Simulation 66/100 (deltaT=2)
# Simulation 67/100 (deltaT=2)
# Simulation 68/100 (deltaT=2)
# Simulation 69/100 (deltaT=2)
# Simulation 70/100 (deltaT=2)
# Simulation 71/100 (deltaT=2)
# Simulation 72/100 (deltaT=2)
# Simulation 73/100 (deltaT=2)
# Simulation 74/100 (deltaT=2)
# Simulation 75/100 (deltaT=2)
# Simulation 76/100 (deltaT=2)
# Simulation 77/100 (deltaT=2)
# Simulation 78/100 (deltaT=2)
# Simulation 79/100 (deltaT=2)
# Simulation 80/100 (deltaT=2)
# Simulation 81/100 (deltaT=2)
# Simulation 82/100 (deltaT=2)
# Simulation 83/100 (deltaT=2)
# Simulation 84/100 (deltaT=2)
# Simulation 85/100 (deltaT=2)
# Simulation 67/100 (deltaT=3)
# Simulation 68/100 (deltaT=3)
# Simulation 69/100 (deltaT=3)
# Simulation 70/100 (deltaT=3)
# Simulation 71/100 (deltaT=3)
# Simulation 72/100 (deltaT=3)
# Simulation 73/100 (deltaT=3)
# Simulation 74/100 (deltaT=3)
# Simulation 75/100 (deltaT=3)
# Simulation 76/100 (deltaT=3)
# Simulation 77/100 (deltaT=3)
# Simulation 78/100 (deltaT=3)
# Simulation 79/100 (deltaT=3)
# Simulation 80/100 (deltaT=3)
# Simulation 81/100 (deltaT=3)
# Simulation 82/100 (deltaT=3)
# Simulation 83/100 (deltaT=3)
# Simulation 84/100 (deltaT=3)
# Simulation 85/100 (deltaT=3)
# Simulation 86/100 (deltaT=3)
# Simulation 87/100 (deltaT=3)
# Simulation 88/100 (deltaT=3)
# Simulation 89/100 (deltaT=3)
# Simulation 90/100 (deltaT=3)
# Simulation 91/100 (deltaT=3)
# Simulation 92/100 (deltaT=3)
# Simulation 93/100 (deltaT=3)
# Simulation 94/100 (deltaT=3)
# Simulation 95/100 (deltaT=3)
# Simulation 96/100 (deltaT=3)
# Simulation 97/100 (deltaT=3)
# Simulation 98/100 (deltaT=3)
# Simulation 99/100 (deltaT=3)
# Simulation 100/100 (deltaT=3)

# %%
f_save = open("./SolutionFolder/MonteCarlo_XULUO_Sample_Fatigue.pkl", 'wb')
pickle.dump(monte_carlo_XULUO_sample, f_save)
f_save.close()

# %%
with open("./SolutionFolder/MonteCarlo_XULUO_Sample_Fatigue.pkl", 'rb') as file:
    monte_carlo_XULUO_sample = pickle.loads(file.read())
    monte_carlo_XULUO_sample = [monte_carlo_XULUO_sample[m]["all_load_served"] 
                                for m in range(len(monte_carlo_XULUO_sample))]
M = len(deltaT_list)
fig = plt.figure(figsize=(6.5, 4))
ax = fig.add_subplot(111)
plt.rc('font', family='Times New Roman', size=15)
colors = sns.color_palette("deep", n_colors=M)
for m in range(0, M-1):
    t = np.arange(0, T, deltaT_list[m]) + deltaT_list[m] / 2
    L_downsampled = downsample(L, deltaT_list[m], 'mean')
    color = colors[m]
    load_served_ratio = monte_carlo_XULUO_sample[m] / L_downsampled
    df = {'Load Served Ratio': [], 'Time (hours)': []}
    for i in range(N_sim):
        df['Load Served Ratio'].extend(load_served_ratio[i])
        df['Time (hours)'].extend(t)
        df['Load Served Ratio'].extend(load_served_ratio[i])
        df['Time (hours)'].extend(t)
    sns.lineplot(
        data=df,
        x='Time (hours)',
        y='Load Served Ratio',
        errorbar=('sd', 0.5),
        label=deltaT_name_list[deltaT_list[m]],
        color=colors[m],
        linewidth=2.5,
    )
plt.ylim(0 - 0.05, 1.05)
plt.xlabel('Time', fontdict={'family': 'times new roman', 'size': 17, 'style': 'normal'})
plt.ylabel('Load Served Ratio', fontdict={'family': 'times new roman', 'size': 17, 'style': 'normal'})
ax.set_xticks(range(0, T+1, 6))
xticklabels = []
for i in range(0, T+1, 6):
    if i <= 24:
        xticklabels.append(f'{i:02d}:00')
    else:
        xticklabels.append(f'{i-24:02d}:00')
ax.set_xticklabels(xticklabels,font={'family': 'times new roman', 'size': 14, 'style': 'normal'},
                   rotation=0)
ax.set_yticks(np.arange(0, 1.01, 0.2))
yticklabels = [f'{i:d}%' for i in np.arange(0, 101, 20)]
ax.set_yticklabels(yticklabels,font={'family': 'times new roman', 'size': 14, 'style': 'normal'},
                   rotation=0)
plt.legend(loc='best',
           prop={'family': 'times new roman', 'size': 14},
           edgecolor='1.0',
           framealpha=0.8
)

ax.grid(axis='both', color='grey', alpha=0.3, linestyle='--', linewidth=1.2)
ax.spines['bottom'].set_linewidth(1.8)
ax.spines['top'].set_linewidth(1.8)
ax.spines['left'].set_linewidth(1.8)
ax.spines['right'].set_linewidth(1.8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## (c)
#
# Method based on conditional probability correction (proposed)

# %%
monte_carlo_past_info_sample = []
for deltaT in deltaT_list:
    print(f">>>deltaT = {deltaT}")
    L_downsampled = downsample(L, deltaT, 'mean')
    w_downsampled = np.zeros((N_sim, round(len(w_example) * BASE_DELTAT / deltaT)))
    for i in range(N_sim):
        w_downsampled[i, :] = downsample(w[i, :], deltaT, 'mean')
    monte_carlo_past_info_sample.append(MonteCarlo_Past_Info_Sample(
                                        n, T, deltaT, N_sim, P_gen,
                                        L_downsampled, w_downsampled, 
                                        fragility_params={'mu': mu, 'sigma': sigma},
                                        prob_method={'name': 'parameter_identification', 
                                                   'para_id_result': para_id_result}
                                        # prob_method={'name': 'abs_resilience'}
                                                     )
                                                     )
# Out:
# >>>deltaT = 0.0008333333333333334
# Simulation 1/100 (deltaT=0.0008333333333333334)
# Simulation 2/100 (deltaT=0.0008333333333333334)
# Simulation 3/100 (deltaT=0.0008333333333333334)
# Simulation 4/100 (deltaT=0.0008333333333333334)
# Simulation 5/100 (deltaT=0.0008333333333333334)
# Simulation 6/100 (deltaT=0.0008333333333333334)
# Simulation 7/100 (deltaT=0.0008333333333333334)
# Simulation 8/100 (deltaT=0.0008333333333333334)
# Simulation 9/100 (deltaT=0.0008333333333333334)
# Simulation 10/100 (deltaT=0.0008333333333333334)
# Simulation 11/100 (deltaT=0.0008333333333333334)
# Simulation 12/100 (deltaT=0.0008333333333333334)
# Simulation 13/100 (deltaT=0.0008333333333333334)
# Simulation 14/100 (deltaT=0.0008333333333333334)
# Simulation 15/100 (deltaT=0.0008333333333333334)
# Simulation 16/100 (deltaT=0.0008333333333333334)
# Simulation 17/100 (deltaT=0.0008333333333333334)
# Simulation 18/100 (deltaT=0.0008333333333333334)
# Simulation 19/100 (deltaT=0.0008333333333333334)
# Simulation 20/100 (deltaT=0.0008333333333333334)
# Simulation 21/100 (deltaT=0.0008333333333333334)
# Simulation 22/100 (deltaT=0.0008333333333333334)
# Simulation 23/100 (deltaT=0.0008333333333333334)
# Simulation 24/100 (deltaT=0.0008333333333333334)
# Simulation 25/100 (deltaT=0.0008333333333333334)
# Simulation 26/100 (deltaT=0.0008333333333333334)
# Simulation 27/100 (deltaT=0.0008333333333333334)
# Simulation 28/100 (deltaT=0.0008333333333333334)
# Simulation 29/100 (deltaT=0.0008333333333333334)
# Simulation 30/100 (deltaT=0.0008333333333333334)
# Simulation 83/100 (deltaT=0.08333333333333333)
# Simulation 84/100 (deltaT=0.08333333333333333)
# Simulation 85/100 (deltaT=0.08333333333333333)
# Simulation 86/100 (deltaT=0.08333333333333333)
# Simulation 87/100 (deltaT=0.08333333333333333)
# Simulation 88/100 (deltaT=0.08333333333333333)
# Simulation 89/100 (deltaT=0.08333333333333333)
# Simulation 90/100 (deltaT=0.08333333333333333)
# Simulation 91/100 (deltaT=0.08333333333333333)
# Simulation 92/100 (deltaT=0.08333333333333333)
# Simulation 93/100 (deltaT=0.08333333333333333)
# Simulation 94/100 (deltaT=0.08333333333333333)
# Simulation 95/100 (deltaT=0.08333333333333333)
# Simulation 96/100 (deltaT=0.08333333333333333)
# Simulation 97/100 (deltaT=0.08333333333333333)
# Simulation 98/100 (deltaT=0.08333333333333333)
# Simulation 99/100 (deltaT=0.08333333333333333)
# Simulation 100/100 (deltaT=0.08333333333333333)
# >>>deltaT = 0.25
# Simulation 1/100 (deltaT=0.25)
# Simulation 2/100 (deltaT=0.25)
# Simulation 3/100 (deltaT=0.25)
# Simulation 4/100 (deltaT=0.25)
# Simulation 5/100 (deltaT=0.25)
# Simulation 6/100 (deltaT=0.25)
# Simulation 7/100 (deltaT=0.25)
# Simulation 8/100 (deltaT=0.25)
# Simulation 9/100 (deltaT=0.25)
# Simulation 10/100 (deltaT=0.25)
# Simulation 11/100 (deltaT=0.25)
# Simulation 12/100 (deltaT=0.25)
# Simulation 13/100 (deltaT=0.25)
# Simulation 14/100 (deltaT=0.25)
# Simulation 15/100 (deltaT=0.25)
# Simulation 16/100 (deltaT=0.25)
# Simulation 17/100 (deltaT=0.25)
# Simulation 18/100 (deltaT=0.25)
# Simulation 19/100 (deltaT=0.25)
# Simulation 20/100 (deltaT=0.25)
# Simulation 21/100 (deltaT=0.25)
# Simulation 22/100 (deltaT=0.25)
# Simulation 23/100 (deltaT=0.25)
# Simulation 24/100 (deltaT=0.25)
# Simulation 25/100 (deltaT=0.25)
# Simulation 26/100 (deltaT=0.25)
# Simulation 27/100 (deltaT=0.25)
# Simulation 28/100 (deltaT=0.25)
# Simulation 29/100 (deltaT=0.25)
# Simulation 30/100 (deltaT=0.25)
# Simulation 31/100 (deltaT=0.25)
# Simulation 32/100 (deltaT=0.25)
# Simulation 33/100 (deltaT=0.25)
# Simulation 34/100 (deltaT=0.25)
# Simulation 35/100 (deltaT=0.25)
# Simulation 36/100 (deltaT=0.25)
# Simulation 37/100 (deltaT=0.25)
# Simulation 38/100 (deltaT=0.25)
# Simulation 39/100 (deltaT=0.25)
# Simulation 40/100 (deltaT=0.25)
# Simulation 41/100 (deltaT=0.25)
# Simulation 42/100 (deltaT=0.25)
# Simulation 43/100 (deltaT=0.25)
# Simulation 44/100 (deltaT=0.25)
# Simulation 45/100 (deltaT=0.25)
# Simulation 46/100 (deltaT=0.25)
# Simulation 47/100 (deltaT=0.25)
# Simulation 48/100 (deltaT=0.25)
# Simulation 49/100 (deltaT=0.25)
# Simulation 50/100 (deltaT=0.25)
# Simulation 51/100 (deltaT=0.25)
# Simulation 52/100 (deltaT=0.25)
# Simulation 53/100 (deltaT=0.25)
# Simulation 54/100 (deltaT=0.25)
# Simulation 55/100 (deltaT=0.25)
# Simulation 56/100 (deltaT=0.25)
# Simulation 57/100 (deltaT=0.25)
# Simulation 58/100 (deltaT=0.25)
# Simulation 59/100 (deltaT=0.25)
# Simulation 60/100 (deltaT=0.25)
# Simulation 61/100 (deltaT=0.25)
# Simulation 62/100 (deltaT=0.25)
# Simulation 63/100 (deltaT=0.25)
# Simulation 64/100 (deltaT=0.25)
# Simulation 65/100 (deltaT=0.25)
# Simulation 66/100 (deltaT=0.25)
# Simulation 67/100 (deltaT=0.25)
# Simulation 68/100 (deltaT=0.25)
# Simulation 69/100 (deltaT=0.25)
# Simulation 70/100 (deltaT=0.25)
# Simulation 71/100 (deltaT=0.25)
# Simulation 72/100 (deltaT=0.25)
# Simulation 73/100 (deltaT=0.25)
# Simulation 74/100 (deltaT=0.25)
# Simulation 75/100 (deltaT=0.25)
# Simulation 76/100 (deltaT=0.25)
# Simulation 77/100 (deltaT=0.25)
# Simulation 78/100 (deltaT=0.25)
# Simulation 79/100 (deltaT=0.25)
# Simulation 80/100 (deltaT=0.25)
# Simulation 81/100 (deltaT=0.25)
# Simulation 82/100 (deltaT=0.25)
# Simulation 83/100 (deltaT=0.25)
# Simulation 84/100 (deltaT=0.25)
# Simulation 85/100 (deltaT=0.25)
# Simulation 86/100 (deltaT=0.25)
# Simulation 87/100 (deltaT=0.25)
# Simulation 88/100 (deltaT=0.25)
# Simulation 89/100 (deltaT=0.25)
# Simulation 90/100 (deltaT=0.25)
# Simulation 91/100 (deltaT=0.25)
# Simulation 92/100 (deltaT=0.25)
# Simulation 93/100 (deltaT=0.25)
# Simulation 94/100 (deltaT=0.25)
# Simulation 95/100 (deltaT=0.25)
# Simulation 96/100 (deltaT=0.25)
# Simulation 97/100 (deltaT=0.25)
# Simulation 98/100 (deltaT=0.25)
# Simulation 99/100 (deltaT=0.25)
# Simulation 100/100 (deltaT=0.25)
# >>>deltaT = 1
# Simulation 1/100 (deltaT=1)
# Simulation 2/100 (deltaT=1)
# Simulation 3/100 (deltaT=1)
# Simulation 4/100 (deltaT=1)
# Simulation 5/100 (deltaT=1)
# Simulation 6/100 (deltaT=1)
# Simulation 7/100 (deltaT=1)
# Simulation 8/100 (deltaT=1)
# Simulation 9/100 (deltaT=1)
# Simulation 10/100 (deltaT=1)
# Simulation 11/100 (deltaT=1)
# Simulation 12/100 (deltaT=1)
# Simulation 13/100 (deltaT=1)
# Simulation 14/100 (deltaT=1)
# Simulation 15/100 (deltaT=1)
# Simulation 16/100 (deltaT=1)
# Simulation 17/100 (deltaT=1)
# Simulation 18/100 (deltaT=1)
# Simulation 19/100 (deltaT=1)
# Simulation 20/100 (deltaT=1)
# Simulation 21/100 (deltaT=1)
# Simulation 22/100 (deltaT=1)
# Simulation 23/100 (deltaT=1)
# Simulation 24/100 (deltaT=1)
# Simulation 25/100 (deltaT=1)
# Simulation 26/100 (deltaT=1)
# Simulation 27/100 (deltaT=1)
# Simulation 28/100 (deltaT=1)
# Simulation 29/100 (deltaT=1)
# Simulation 30/100 (deltaT=1)
# Simulation 31/100 (deltaT=1)
# Simulation 32/100 (deltaT=1)
# Simulation 33/100 (deltaT=1)
# Simulation 34/100 (deltaT=1)
# Simulation 35/100 (deltaT=1)
# Simulation 36/100 (deltaT=1)
# Simulation 37/100 (deltaT=1)
# Simulation 38/100 (deltaT=1)
# Simulation 39/100 (deltaT=1)
# Simulation 40/100 (deltaT=1)
# Simulation 41/100 (deltaT=1)
# Simulation 42/100 (deltaT=1)
# Simulation 43/100 (deltaT=1)
# Simulation 44/100 (deltaT=1)
# Simulation 45/100 (deltaT=1)
# Simulation 46/100 (deltaT=1)
# Simulation 47/100 (deltaT=1)
# Simulation 48/100 (deltaT=1)
# Simulation 49/100 (deltaT=1)
# Simulation 50/100 (deltaT=1)
# Simulation 51/100 (deltaT=1)
# Simulation 52/100 (deltaT=1)
# Simulation 53/100 (deltaT=1)
# Simulation 54/100 (deltaT=1)
# Simulation 55/100 (deltaT=1)
# Simulation 56/100 (deltaT=1)
# Simulation 57/100 (deltaT=1)
# Simulation 58/100 (deltaT=1)
# Simulation 59/100 (deltaT=1)
# Simulation 60/100 (deltaT=1)
# Simulation 61/100 (deltaT=1)
# Simulation 62/100 (deltaT=1)
# Simulation 63/100 (deltaT=1)
# Simulation 64/100 (deltaT=1)
# Simulation 65/100 (deltaT=1)
# Simulation 66/100 (deltaT=1)
# Simulation 67/100 (deltaT=1)
# Simulation 68/100 (deltaT=1)
# Simulation 69/100 (deltaT=1)
# Simulation 70/100 (deltaT=1)
# Simulation 71/100 (deltaT=1)
# Simulation 72/100 (deltaT=1)
# Simulation 73/100 (deltaT=1)
# Simulation 74/100 (deltaT=1)
# Simulation 75/100 (deltaT=1)
# Simulation 76/100 (deltaT=1)
# Simulation 77/100 (deltaT=1)
# Simulation 78/100 (deltaT=1)
# Simulation 79/100 (deltaT=1)
# Simulation 80/100 (deltaT=1)
# Simulation 81/100 (deltaT=1)
# Simulation 82/100 (deltaT=1)
# Simulation 83/100 (deltaT=1)
# Simulation 84/100 (deltaT=1)
# Simulation 85/100 (deltaT=1)
# Simulation 86/100 (deltaT=1)
# Simulation 87/100 (deltaT=1)
# Simulation 88/100 (deltaT=1)
# Simulation 89/100 (deltaT=1)
# Simulation 90/100 (deltaT=1)
# Simulation 91/100 (deltaT=1)
# Simulation 92/100 (deltaT=1)
# Simulation 93/100 (deltaT=1)
# Simulation 94/100 (deltaT=1)
# Simulation 95/100 (deltaT=1)
# Simulation 96/100 (deltaT=1)
# Simulation 97/100 (deltaT=1)
# Simulation 98/100 (deltaT=1)
# Simulation 99/100 (deltaT=1)
# Simulation 100/100 (deltaT=1)
# >>>deltaT = 2
# Simulation 1/100 (deltaT=2)
# Simulation 2/100 (deltaT=2)
# Simulation 3/100 (deltaT=2)
# Simulation 4/100 (deltaT=2)
# Simulation 5/100 (deltaT=2)
# Simulation 6/100 (deltaT=2)
# Simulation 7/100 (deltaT=2)
# Simulation 8/100 (deltaT=2)
# Simulation 9/100 (deltaT=2)
# Simulation 10/100 (deltaT=2)
# Simulation 11/100 (deltaT=2)
# Simulation 12/100 (deltaT=2)
# Simulation 13/100 (deltaT=2)
# Simulation 14/100 (deltaT=2)
# Simulation 15/100 (deltaT=2)
# Simulation 16/100 (deltaT=2)
# Simulation 17/100 (deltaT=2)
# Simulation 18/100 (deltaT=2)
# Simulation 19/100 (deltaT=2)
# Simulation 20/100 (deltaT=2)
# Simulation 21/100 (deltaT=2)
# Simulation 22/100 (deltaT=2)
# Simulation 23/100 (deltaT=2)
# Simulation 24/100 (deltaT=2)
# Simulation 25/100 (deltaT=2)
# Simulation 26/100 (deltaT=2)
# Simulation 27/100 (deltaT=2)
# Simulation 28/100 (deltaT=2)
# Simulation 29/100 (deltaT=2)
# Simulation 30/100 (deltaT=2)
# Simulation 31/100 (deltaT=2)
# Simulation 32/100 (deltaT=2)
# Simulation 33/100 (deltaT=2)
# Simulation 34/100 (deltaT=2)
# Simulation 35/100 (deltaT=2)
# Simulation 36/100 (deltaT=2)
# Simulation 37/100 (deltaT=2)
# Simulation 38/100 (deltaT=2)
# Simulation 39/100 (deltaT=2)
# Simulation 40/100 (deltaT=2)
# Simulation 41/100 (deltaT=2)
# Simulation 42/100 (deltaT=2)
# Simulation 43/100 (deltaT=2)
# Simulation 44/100 (deltaT=2)
# Simulation 45/100 (deltaT=2)
# Simulation 46/100 (deltaT=2)
# Simulation 47/100 (deltaT=2)
# Simulation 48/100 (deltaT=2)
# Simulation 49/100 (deltaT=2)
# Simulation 50/100 (deltaT=2)
# Simulation 51/100 (deltaT=2)
# Simulation 52/100 (deltaT=2)
# Simulation 53/100 (deltaT=2)
# Simulation 54/100 (deltaT=2)
# Simulation 55/100 (deltaT=2)
# Simulation 56/100 (deltaT=2)
# Simulation 57/100 (deltaT=2)
# Simulation 58/100 (deltaT=2)
# Simulation 59/100 (deltaT=2)
# Simulation 60/100 (deltaT=2)
# Simulation 61/100 (deltaT=2)
# Simulation 62/100 (deltaT=2)
# Simulation 63/100 (deltaT=2)
# Simulation 64/100 (deltaT=2)
# Simulation 65/100 (deltaT=2)
# Simulation 66/100 (deltaT=2)
# Simulation 67/100 (deltaT=2)
# Simulation 68/100 (deltaT=2)
# Simulation 69/100 (deltaT=2)
# Simulation 70/100 (deltaT=2)
# Simulation 71/100 (deltaT=2)
# Simulation 72/100 (deltaT=2)
# Simulation 73/100 (deltaT=2)
# Simulation 74/100 (deltaT=2)
# Simulation 75/100 (deltaT=2)
# Simulation 76/100 (deltaT=2)
# Simulation 77/100 (deltaT=2)
# Simulation 78/100 (deltaT=2)
# Simulation 79/100 (deltaT=2)
# Simulation 80/100 (deltaT=2)
# Simulation 81/100 (deltaT=2)
# Simulation 82/100 (deltaT=2)
# Simulation 83/100 (deltaT=2)
# Simulation 84/100 (deltaT=2)
# Simulation 85/100 (deltaT=2)
# Simulation 86/100 (deltaT=2)
# Simulation 87/100 (deltaT=2)
# Simulation 88/100 (deltaT=2)
# Simulation 89/100 (deltaT=2)
# Simulation 71/100 (deltaT=3)
# Simulation 72/100 (deltaT=3)
# Simulation 73/100 (deltaT=3)
# Simulation 74/100 (deltaT=3)
# Simulation 75/100 (deltaT=3)
# Simulation 76/100 (deltaT=3)
# Simulation 77/100 (deltaT=3)
# Simulation 78/100 (deltaT=3)
# Simulation 79/100 (deltaT=3)
# Simulation 80/100 (deltaT=3)
# Simulation 81/100 (deltaT=3)
# Simulation 82/100 (deltaT=3)
# Simulation 83/100 (deltaT=3)
# Simulation 84/100 (deltaT=3)
# Simulation 85/100 (deltaT=3)
# Simulation 86/100 (deltaT=3)
# Simulation 87/100 (deltaT=3)
# Simulation 88/100 (deltaT=3)
# Simulation 89/100 (deltaT=3)
# Simulation 90/100 (deltaT=3)
# Simulation 91/100 (deltaT=3)
# Simulation 92/100 (deltaT=3)
# Simulation 93/100 (deltaT=3)
# Simulation 94/100 (deltaT=3)
# Simulation 95/100 (deltaT=3)
# Simulation 96/100 (deltaT=3)
# Simulation 97/100 (deltaT=3)
# Simulation 98/100 (deltaT=3)
# Simulation 99/100 (deltaT=3)
# Simulation 100/100 (deltaT=3)

# %%
f_save = open("./SolutionFolder/MonteCarlo_Past_Info_Sample_Fatigue.pkl", 'wb')
pickle.dump(monte_carlo_past_info_sample, f_save)
f_save.close()

# %%
with open("./SolutionFolder/MonteCarlo_Past_Info_Sample_Fatigue.pkl", 'rb') as file:
    monte_carlo_past_info_sample = pickle.loads(file.read())
    monte_carlo_past_info_sample = [monte_carlo_past_info_sample[m]["all_load_served"] 
                                    for m in range(len(monte_carlo_past_info_sample))]
M = len(deltaT_list)
fig = plt.figure(figsize=(6.5, 4))
ax = fig.add_subplot(111)
plt.rc('font', family='Times New Roman', size=15)
colors = sns.color_palette("deep", n_colors=M)
for m in range(0, M-1):
    t = np.arange(0, T, deltaT_list[m]) + deltaT_list[m] / 2
    L_downsampled = downsample(L, deltaT_list[m], 'mean')
    color = colors[m]
    load_served_ratio = monte_carlo_past_info_sample[m] / L_downsampled
    df = {'Load Served Ratio': [], 'Time (hours)': []}
    for i in range(N_sim):
        df['Load Served Ratio'].extend(load_served_ratio[i])
        df['Time (hours)'].extend(t)
        df['Load Served Ratio'].extend(load_served_ratio[i])
        df['Time (hours)'].extend(t)
    sns.lineplot(
        data=df,
        x='Time (hours)',
        y='Load Served Ratio',
        errorbar=('sd', 0.5),
        label=deltaT_name_list[deltaT_list[m]],
        color=colors[m],
        linewidth=2.5,
    )

plt.ylim(0 - 0.05, 1.05)
plt.xlabel('Time', fontdict={'family': 'times new roman', 'size': 17, 'style': 'normal'})
plt.ylabel('Load Served Ratio', fontdict={'family': 'times new roman', 'size': 17, 'style': 'normal'})
ax.set_xticks(range(0, T+1, 6))
xticklabels = []
for i in range(0, T+1, 6):
    if i <= 24:
        xticklabels.append(f'{i:02d}:00')
    else:
        xticklabels.append(f'{i-24:02d}:00')
ax.set_xticklabels(xticklabels,font={'family': 'times new roman', 'size': 14, 'style': 'normal'},
                   rotation=0)
ax.set_yticks(np.arange(0, 1.01, 0.2))
yticklabels = [f'{i:d}%' for i in np.arange(0, 101, 20)]
ax.set_yticklabels(yticklabels,font={'family': 'times new roman', 'size': 14, 'style': 'normal'},
                   rotation=0)
plt.legend(loc='best',
           prop={'family': 'times new roman', 'size': 14},
           edgecolor='1.0',
           framealpha=0.8
)

ax.grid(axis='both', color='grey', alpha=0.3, linestyle='--', linewidth=1.2)
ax.spines['bottom'].set_linewidth(1.8)
ax.spines['top'].set_linewidth(1.8)
ax.spines['left'].set_linewidth(1.8)
ax.spines['right'].set_linewidth(1.8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## (d)
#
# Benchmark

# %%
monte_carlo_Fatigue_Accumulation_sample = []
for deltaT in deltaT_list:
    deltaT = BASE_DELTAT # A Benchmark is based on the underlying physical mechanisms as the standard answer, using the finest studied resolution.
    print(f">>>deltaT = {deltaT}")
    L_downsampled = downsample(L, deltaT, 'mean')
    w_downsampled = np.zeros((N_sim, round(len(w_example) * BASE_DELTAT / deltaT)))
    for i in range(N_sim):
        w_downsampled[i, :] = downsample(w[i, :], deltaT, 'mean')   
    monte_carlo_Fatigue_Accumulation_sample.append(MonteCarlo_Fatigue_Accumulation_Sample(
                                        n, T, deltaT, N_sim, P_gen,
                                        L_downsampled, w_downsampled, 
                                        fragility_params={'a': a, 'b': b, 'v0': v0, 'vmax': vmax, 'Dres': Dres}))
    break
# Out:
# >>>deltaT = 0.0008333333333333334
# Simulation 1/100 (deltaT=0.0008333333333333334)
# Simulation 2/100 (deltaT=0.0008333333333333334)
# Simulation 3/100 (deltaT=0.0008333333333333334)
# Simulation 4/100 (deltaT=0.0008333333333333334)
# Simulation 5/100 (deltaT=0.0008333333333333334)
# Simulation 6/100 (deltaT=0.0008333333333333334)
# Simulation 7/100 (deltaT=0.0008333333333333334)
# Simulation 8/100 (deltaT=0.0008333333333333334)
# Simulation 9/100 (deltaT=0.0008333333333333334)
# Simulation 10/100 (deltaT=0.0008333333333333334)
# Simulation 11/100 (deltaT=0.0008333333333333334)
# Simulation 12/100 (deltaT=0.0008333333333333334)
# Simulation 13/100 (deltaT=0.0008333333333333334)
# Simulation 14/100 (deltaT=0.0008333333333333334)
# Simulation 15/100 (deltaT=0.0008333333333333334)
# Simulation 16/100 (deltaT=0.0008333333333333334)
# Simulation 17/100 (deltaT=0.0008333333333333334)
# Simulation 18/100 (deltaT=0.0008333333333333334)
# Simulation 19/100 (deltaT=0.0008333333333333334)
# Simulation 20/100 (deltaT=0.0008333333333333334)
# Simulation 21/100 (deltaT=0.0008333333333333334)
# Simulation 22/100 (deltaT=0.0008333333333333334)
# Simulation 23/100 (deltaT=0.0008333333333333334)
# Simulation 24/100 (deltaT=0.0008333333333333334)
# Simulation 25/100 (deltaT=0.0008333333333333334)
# Simulation 26/100 (deltaT=0.0008333333333333334)
# Simulation 27/100 (deltaT=0.0008333333333333334)
# Simulation 28/100 (deltaT=0.0008333333333333334)
# Simulation 29/100 (deltaT=0.0008333333333333334)
# Simulation 30/100 (deltaT=0.0008333333333333334)
# Simulation 31/100 (deltaT=0.0008333333333333334)
# Simulation 32/100 (deltaT=0.0008333333333333334)
# Simulation 90/100 (deltaT=0.0008333333333333334)
# Simulation 91/100 (deltaT=0.0008333333333333334)
# Simulation 92/100 (deltaT=0.0008333333333333334)
# Simulation 93/100 (deltaT=0.0008333333333333334)
# Simulation 94/100 (deltaT=0.0008333333333333334)
# Simulation 95/100 (deltaT=0.0008333333333333334)
# Simulation 96/100 (deltaT=0.0008333333333333334)
# Simulation 97/100 (deltaT=0.0008333333333333334)
# Simulation 98/100 (deltaT=0.0008333333333333334)
# Simulation 99/100 (deltaT=0.0008333333333333334)
# Simulation 100/100 (deltaT=0.0008333333333333334)

# %%
f_save = open("./SolutionFolder/MonteCarlo_Fatigue_Accumulation_Sample_Fatigue.pkl", 'wb')
pickle.dump(monte_carlo_Fatigue_Accumulation_sample, f_save)
f_save.close()

# %%
with open("./SolutionFolder/MonteCarlo_Fatigue_Accumulation_Sample_Fatigue.pkl", 'rb') as file:
    monte_carlo_Fatigue_Accumulation_sample = pickle.loads(file.read())
    monte_carlo_Fatigue_Accumulation_sample = \
        [monte_carlo_Fatigue_Accumulation_sample[m]["all_load_served"] 
         for m in range(len(monte_carlo_Fatigue_Accumulation_sample))]
M = len(deltaT_list)
fig = plt.figure(figsize=(6.5, 4))
ax = fig.add_subplot(111)
plt.rc('font', family='Times New Roman', size=15)
colors = sns.color_palette("deep", n_colors=M)
for m in range(0, M):
    deltaT_list_m = BASE_DELTAT
    t = np.arange(0, T, deltaT_list_m) + deltaT_list_m / 2
    L_downsampled = downsample(L, deltaT_list_m, method='mean')
    color = colors[m]
    load_served_ratio = monte_carlo_Fatigue_Accumulation_sample[m] / L_downsampled
    df = {'Load Served Ratio': [], 'Time (hours)': []}
    for i in range(0, N_sim):
        df['Load Served Ratio'].extend(load_served_ratio[i])
        df['Time (hours)'].extend(t)
        df['Load Served Ratio'].extend(load_served_ratio[i])
        df['Time (hours)'].extend(t)
    sns.lineplot(
        data=df,
        x='Time (hours)',
        y='Load Served Ratio',
        errorbar=None,
        color=colors[m],
        linewidth=2.8,
    )
    break

plt.ylim(0 - 0.05, 1.05)
plt.xlabel('Time', fontdict={'family': 'times new roman', 'size': 17, 'style': 'normal'})
plt.ylabel('Load Served Ratio', fontdict={'family': 'times new roman', 'size': 17, 'style': 'normal'})
ax.set_xticks(range(0, T+1, 6))
xticklabels = []
for i in range(0, T+1, 6):
    if i <= 24:
        xticklabels.append(f'{i:02d}:00')
    else:
        xticklabels.append(f'{i-24:02d}:00')
ax.set_xticklabels(xticklabels,font={'family': 'times new roman', 'size': 14, 'style': 'normal'},
                   rotation=0)
ax.set_yticks(np.arange(0, 1.01, 0.2))
yticklabels = [f'{i:d}%' for i in np.arange(0, 101, 20)]
ax.set_yticklabels(yticklabels,font={'family': 'times new roman', 'size': 14, 'style': 'normal'},
                   rotation=0)

ax.grid(axis='both', color='grey', alpha=0.3, linestyle='--', linewidth=1.2)
ax.spines['bottom'].set_linewidth(1.8)
ax.spines['top'].set_linewidth(1.8)
ax.spines['left'].set_linewidth(1.8)
ax.spines['right'].set_linewidth(1.8)

plt.tight_layout()
plt.show()
